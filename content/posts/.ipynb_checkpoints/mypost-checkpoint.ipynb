# %% [markdown]
# $$c = \sqrt{a^2 + b^2 + c^3}$$

# %% [markdown]
# ## How about some markdown content?
#
# ## jgjkjhkjhkjk
#
# Can we add `markdown` here?
#
# Is all works well and good but if we let the line go for long enough we may see that it doesn't wrap appropriately. Will this wrap?

# %%
#and so that was fine but what about this?

some_long_test_array = [1,2,3,4,5,500000000, 600000000, 70000000, 
                        75000000, 800000000, 8500000, 9000000, 10000000, 110000]

# %%
import sympy as sm
import numpy as np

import matplotlib.pyplot as plt

# %matplotlib inline
sm.init_printing()

# %%
x = sm.Symbol('x')

# %%
y = x**2 + 1

# %%
yprime = y.diff(x)

# %%
yprime
# Out:
# 2⋅x

# %%
yprime2 = yprime.diff(x)

# %%
yprime2
# Out:
# 2

# %%
x_vals = np.arange(0,5,0.5)
f = sm.lambdify(x, y, 'numpy')
f_prime = sm.lambdify(x, yprime, 'numpy')
f_prime2 = sm.lambdify(x, yprime2, 'numpy')

# %%
# Out:
# <function numpy.<lambda>>

# %% [markdown]
# > Note that there is currently an issue with sympy's ability to lambdify constant expressions. There's an open PR about it [here](https://github.com/sympy/sympy/issues/5642)

# %%
plt.plot(x_vals, f(x_vals))
plt.plot(x_vals, f_prime(x_vals))
#plt.plot(x_vals, f_prime2(x_vals))
plt.plot(x_vals, [ 5 for i in range(len(x_vals)) ])
plt.show()

# %%
yprime
# Out:
# 2⋅x

# %%
radians(60)

x_vals = np.linspace(0,10)
y = sm.sin(x)

integ_sin = sm.integrate(sm.sin(x))

plt.plot(x_vals, sm.lambdify(x, y, 'numpy')(x_vals))
plt.plot(x_vals, sm.lambdify(x, integ_sin, 'numpy')(x_vals))

plt.plot(x_vals, sm.lambdify(x, y.diff(x), 'numpy')(x_vals))

# %%
from mpmath import *

# %%
x_vals = np.linspace(-10,10, 100)
y = 1/x

plt.plot(x_vals, sm.lambdify(x, y, 'numpy')(x_vals))

# %%
x_vals
# Out:
# array([-10.        ,  -9.59183673,  -9.18367347,  -8.7755102 ,
#         -8.36734694,  -7.95918367,  -7.55102041,  -7.14285714,
#         -6.73469388,  -6.32653061,  -5.91836735,  -5.51020408,
#         -5.10204082,  -4.69387755,  -4.28571429,  -3.87755102,
#         -3.46938776,  -3.06122449,  -2.65306122,  -2.24489796,
#         -1.83673469,  -1.42857143,  -1.02040816,  -0.6122449 ,
#         -0.20408163,   0.20408163,   0.6122449 ,   1.02040816,
#          1.42857143,   1.83673469,   2.24489796,   2.65306122,
#          3.06122449,   3.46938776,   3.87755102,   4.28571429,
#          4.69387755,   5.10204082,   5.51020408,   5.91836735,
#          6.32653061,   6.73469388,   7.14285714,   7.55102041,
#          7.95918367,   8.36734694,   8.7755102 ,   9.18367347,
#          9.59183673,  10.        ])

# %%
import pandas as pd

# %%
pd.DataFrame({'a': [1,2,3], 'b':[4,5,6], 'c':[6,7,8], 'd':[7,8,9]})
# Out:
#    a  b  c  d
# 0  1  4  6  7
# 1  2  5  7  8
# 2  3  6  8  9

# %%
sm.plot(sm.sin(1/x), (x, -5, 5))

# %%
sm.plot(1/sm.tan(x), (x, -5, 5), yscale='linear')

# %%
p1 = sm.plot(sm.sin(x)/x, (x,-100,100))
p2 = sm.plot(1/x, (x, 0.2, 100))

p1.append(p2[0])

# %%
domain = np.linspace(2, 100, 300)

plt.plot(domain, sm.lambdify(x, sm.sin(x)/x, 'numpy')(domain))
plt.plot(domain, sm.lambdify(x, 1/x, 'numpy')(domain))
plt.plot(domain, sm.lambdify(x, -1/x, 'numpy')(domain))

# %%
domain = np.arange(0,100)
plt.plot(domain, sm.lambdify(x, x, 'numpy')(domain))
plt.plot(domain, sm.lambdify(x, ((x+40)/2), 'numpy')(domain))

# %%
(x+100)/2
# Out:
# x
# ─ + 50
# 2

# %%
123456
# Out:
# 123456

# %%
np.linspace(2, 100, 100)
# Out:
# array([   2.        ,    2.98989899,    3.97979798,    4.96969697,
#           5.95959596,    6.94949495,    7.93939394,    8.92929293,
#           9.91919192,   10.90909091,   11.8989899 ,   12.88888889,
#          13.87878788,   14.86868687,   15.85858586,   16.84848485,
#          17.83838384,   18.82828283,   19.81818182,   20.80808081,
#          21.7979798 ,   22.78787879,   23.77777778,   24.76767677,
#          25.75757576,   26.74747475,   27.73737374,   28.72727273,
#          29.71717172,   30.70707071,   31.6969697 ,   32.68686869,
#          33.67676768,   34.66666667,   35.65656566,   36.64646465,
#          37.63636364,   38.62626263,   39.61616162,   40.60606061,
#          41.5959596 ,   42.58585859,   43.57575758,   44.56565657,
#          45.55555556,   46.54545455,   47.53535354,   48.52525253,
#          49.51515152,   50.50505051,   51.49494949,   52.48484848,
#          53.47474747,   54.46464646,   55.45454545,   56.44444444,
#          57.43434343,   58.42424242,   59.41414141,   60.4040404 ,
#          61.39393939,   62.38383838,   63.37373737,   64.36363636,
#          65.35353535,   66.34343434,   67.33333333,   68.32323232,
#          69.31313131,   70.3030303 ,   71.29292929,   72.28282828,
#          73.27272727,   74.26262626,   75.25252525,   76.24242424,
#          77.23232323,   78.22222222,   79.21212121,   80.2020202 ,
#          81.19191919,   82.18181818,   83.17171717,   84.16161616,
#          85.15151515,   86.14141414,   87.13131313,   88.12121212,
#          89.11111111,   90.1010101 ,   91.09090909,   92.08080808,
#          93.07070707,   94.06060606,   95.05050505,   96.04040404,
#          97.03030303,   98.02020202,   99.01010101,  100.        ])
